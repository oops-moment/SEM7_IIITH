# %% [markdown]
# # Question Generator command line example

# %% [markdown]
# First we need to install HuggingFace's transformers library.

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (4.45.2)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: numpy>=1.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /Users/prisha/Library/Python/3.12/lib/python/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->transformers) (2024.8.30)

# %% [markdown]
# Next we're going to clone the github repo.

# %%
# !git clone https://github.com/amontgomerie/question_generator
# Out:
# Cloning into 'question_generator'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 80 (delta 36), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (80/80), done.
# /content/question_generator

# %%
# %cd question_generator/
# Out:
# /Users/prisha/Documents/SEM7/Refer/question_generator
# /Users/prisha/Library/Python/3.12/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# Make sure that we're using the GPU:

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# assert device == torch.device('cuda'), "Not using CUDA. Set: Runtime > Change runtime type > Hardware Accelerator: GPU"

# %% [markdown]
# Finally we can run question generation script using the following arguments:
# ```
# --text_dir # the directory of the artice to use as context
# --num_questions # the number of questions to be generated (default 10)
# --answer_style # can be 'all', 'sentences', or 'multiple_choice' (default 'all')
# --show_answers # set to 'False' to hide answers (default 'True')
# --use_qa_eval # use to turn off the question filtering 'True'/'False' (default True)
# ```

# %%
# !python3 'run_qg.py' --text_file 'articles/twitter_hack.txt'
# Out:
# /Users/prisha/Documents/SEM7/Refer/question_generator/questiongenerator.py:143: SyntaxWarning: invalid escape sequence '\?'
#   sentences = re.findall(".*?[.!\?]", text)
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Generating questions...
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/generation/utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Evaluating QA pairs...
#
# 1) Q: What is the name of the website that was used to register?
#    A: The name "Anthony Elias" was used to register the website, but may be a pseudonym - it appears to be a play on "an alias".
#
# 2) Q: What was the name of the website where some hacked tweets were directed?
#    A: com - to which some hacked tweets directed users was registered by a cyber-attacker using the email address mkeyworth5@gmail.
#
# 3) Q: What did the campaign of Joe Biden say about the hack?
#    A: The campaign of Joe Biden, who is the current Democratic presidential candidate, said Twitter had "locked down the account within a few minutes of the breach and removed the related tweet".
#
# 4) Q: What other people were targeted?
#    A: Others targeted included reality TV star Kim Kardashian West, former US President Obama, media billionaire Mike Bloomberg, the ride-sharing app Uber, and the iPhone-maker Apple.
#
# 5) Q: What is the name of the website that was hacked?
#    A: Cryptoforhealth is also a registered user name on Instagram, apparently set up contemporaneously to the hack.
#
# 6) Q: What did the FBI say about the hack?
#    A: "We know they [the hackers] used this access to take control of many highly-visible (including verified) accounts and Tweet on their behalf," the company said in a series of tweets.
#
# 7) Q: What's the name of the hack?
#    A: Dmitri Alperovitch, who co-founded cyber-security company CrowdStrike, told Reuters news agency: "This appears to be the worst hack of a major social media platform yet.
#
# 8) Q: What happened to the first tweet from Mr Musk's account?
#    A: But as the first such tweet from Mr Musk's account was removed, another one appeared, then a third.
#
# 9) Q: How long after the tweets were first posted?
#    A: 1. the next 30 minutes
#       2. just minutes (correct)
#       3. a few minutes
#       4. 20:30 EDT
#
# 10) Q: What is the point of the attack?
#     A: But whatever the source of this attack [it seems they have] still not done enough.
