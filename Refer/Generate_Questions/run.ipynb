# %% [markdown]
# # Question Generator command line example

# %% [markdown]
# First we need to install HuggingFace's transformers library.

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (4.45.2)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: numpy>=1.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /Users/prisha/Library/Python/3.12/lib/python/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->transformers) (2024.8.30)

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# assert device == torch.device('cuda'), "Not using CUDA. Set: Runtime > Change runtime type > Hardware Accelerator: GPU"

# %%
# !python3 'run_qg.py' --text_file 'test.txt'
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Question Generation Started
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/generation/utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Evaluating QA pairs...
#
# 1) Q: What was the first time that the distinction between amateurs and professionals became blurred?
#    A: It was especially during the career of Grace that the distinction between amateurs and professionals became blurred by the existence of players like him who were nominally amateur but, in terms of their financial gain, de facto professional.
#
# 2) Q: When did cricket spread globally?
#    A: It spread globally with the expansion of the British Empire, with the first international matches in the second half of the 19th century.
#
# 3) Q: What is the key difference between cricket and baseball?
#    A: [4] In cricket's case, a key difference is the existence of a solid target structure, the wicket (originally, it is thought, a "wicket gate" through which sheep were herded), that the batter must defend.
#
# 4) Q: What was the first international match between what were essentially club teams?
#    A: [46] Cricket becomes an international sport The first English team to tour overseas, on board ship to North America, 1859 In 1844, the first-ever international match took place between what were essentially club teams, from the United States and Canada, in Toronto; Canada won.
#
# 5) Q: What is the difference between cricket and baseball?
#    A: Others include baseball (which shares many similarities with cricket, both belonging in the more specific bat-and-ball games category[3]), golf, hockey, tennis, squash, badminton and table tennis.
#
# 6) Q: What was the first recorded photo of a cricket match taken on 25 July 1857?
#    A: [45] The first recorded photo of a cricket match taken on 25 July 1857 by Roger Fenton The most famous player of the 19th century was W.
#
# 7) Q: How many Tests has Australia won?
#    A: The most successful side playing international cricket is Australia, which has won eight One Day International trophies, including six World Cups, more than any other country, and has been the top-rated Test side more than any other country.
#
# 8) Q: Who was the greatest Test batter of all time?
#    A: 1. Richard Latter
#       2. krik ket)sen
#       3. Surrey
#       4. Don Bradman (correct)
#
# 9) Q: What is the meaning of cricket?
#    A: Cricket is one of many games in the "club ball" sphere that involve hitting a ball with a hand-held implement.
#
# 10) Q: Where is the sport played?
#     A: The sport is followed primarily in South Asia, Australia, New Zealand, the United Kingdom, Southern Africa, and the West Indies.

# %%
# !python3 'run_qg.py' --text_file 'test.txt'
# Out:
# /Users/prisha/Documents/SEM7/Refer/Generate_Questions/questiongenerator.py:132: SyntaxWarning: invalid escape sequence '\?'
#   sentences = re.findall(".*?[.!\?]", text)
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Question Generation Started
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/generation/utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Evaluating QA pairs...
#
# 1) Q: question: What was the gentry's obligation to claim leadership in sporting contests?
#    A: [33] The gentry, including such high-ranking nobles as the Dukes of Richmond, exerted their honour code of noblesse oblige to claim rights of leadership in any sporting contests they took part in, especially as it was necessary for them to play alongside their "social inferiors" if they were to win their bets.
#
# 2) Q: question: As teams began to travel more, the game quickly grew from 500 tests to 1000?
#    A: As teams began to travel more, the game quickly grew from 500 tests in 84 years to 1000 within the next 23.
#
# 3) Q: question: What was the success of cricket underwritten by?
#    A: [38] Its success was underwritten by the twin necessities of patronage and betting.
#
# 4) Q: question: What perception did society take of the typical amateur cricketer?
#    A: [34] In time, a perception took hold that the typical amateur who played in first-class cricket, until 1962 when amateurism was abolished, was someone with a public school education who had then gone to one of Cambridge or Oxford University.
#
# 5) Q: question: What was the derisive term for amateur cricket?
#    A: [35] In a purely financial sense, the cricketing amateur would theoretically claim expenses for playing while his professional counterpart played under contract and was paid a wage or match fee; in practice, many amateurs claimed more than actual expenditure, and the derisive term "shamateur" was coined to describe the practice.
#
# 6) Q: question: What was the popularity of cricket in the 1748 season?
#    A: [citation needed] The single wicket form of the sport attracted huge crowds and wagers to match, its popularity peaking in the 1748 season.
#
# 7) Q: question: In 1624, a player died after he was accidentally struck on the head?
#    A: [7][20] In 1624, a player called Jasper Vinall died after he was accidentally struck on the head during a match between two parish teams in Sussex.
#
# 8) Q: question: What is the name of the sport that was a great upsurge after the?
#    A: [24][25] According to the social historian Derek Birley, there was a "great upsurge of sport after the Restoration" in 1660.
#
# 9) Q: question: What is the earliest reference to cricket overseas?
#    A: [29] By the end of the century, cricket had developed into a major sport that was spreading throughout England and was already being taken abroad by English mariners and colonisers—the earliest reference to cricket overseas is dated 1676.
#
# 10) Q: question: What is one possible source for the sport's name?
#     A: [10][11] One possible source for the sport's name is the Old English word "cryce" (or "cricc") meaning a crutch or staff.
